# %%
# All Required imports
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
def preProcessData(data):
    test_df = data.drop(['Ticket','Name','PassengerId','Cabin'], axis=1)
    test_df['Female'] = test_df['Sex'] == 'female'
    test_df = test_df.drop('Sex', axis=1)
    test_df['Embarked'] = test_df['Embarked'] == 'S'
    test_df = test_df.dropna()
    return test_df

# %%
class TitanicDataset(Dataset):
    def __init__(self, data_set):
        self.data_set = data_set
    def __len__(self):
        return len(self.data_set)

    def __getitem__(self, idx):
        print(f"Index: {idx}")
        data = torch.tensor(self.data_set.iloc[idx, self.data_set.columns != 'Survived'], dtype=torch.float32)
        label = nn.functional.one_hot(torch.tensor(self.data_set.iloc[idx, self.data_set.columns == 'Survived'], dtype=torch.int64),num_classes=2)
        return data, label

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork,self).__init__()
        self.simple_stack = nn.Sequential(
            nn.Linear(7, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 2),
        )
        
    def forward(self, x):
        x = self.simple_stack(x)
        return x

# %%
num_epochs = 5
batch_size = 2
lr = 0.005

# %%
ptrain_data = TitanicDataset(preProcessData(train_data))
ptest_data = TitanicDataset(preProcessData(test_data))
print(ptrain_data.data_set[0:15])
print(ptrain_data.data_set.iloc[5, ptrain_data.data_set.columns != 'Survived'])
print(ptrain_data.data_set.loc[890, ptrain_data.data_set.columns != 'Survived'])
train_dataloader = DataLoader(ptrain_data, batch_size=1, shuffle=True)
test_dataloader = DataLoader(ptest_data, batch_size=4, shuffle=True)
# Out:
#     Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  Female
# 0          0       3  22.0      1      0   7.2500      True   False
# 1          1       1  38.0      1      0  71.2833     False    True
# 2          1       3  26.0      0      0   7.9250      True    True
# 3          1       1  35.0      1      0  53.1000      True    True
# 4          0       3  35.0      0      0   8.0500      True   False
# 6          0       1  54.0      0      0  51.8625      True   False
# 7          0       3   2.0      3      1  21.0750      True   False
# 8          1       3  27.0      0      2  11.1333      True    True
# 9          1       2  14.0      1      0  30.0708     False    True
# 10         1       3   4.0      1      1  16.7000      True    True
# 11         1       1  58.0      0      0  26.5500      True    True
# 12         0       3  20.0      0      0   8.0500      True   False
# 13         0       3  39.0      1      5  31.2750      True   False
# 14         0       3  14.0      0      0   7.8542      True    True
# 15         1       2  55.0      0      0  16.0000      True    True
# Pclass            1
# Age            54.0
# SibSp             0
# Parch             0
# Fare        51.8625
# Embarked       True
# Female        False
# Name: 6, dtype: object
# Pclass          3
# Age          32.0
# SibSp           0
# Parch           0
# Fare         7.75
# Embarked    False
# Female      False
# Name: 890, dtype: object

# %%
model = NeuralNetwork().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = nn.CrossEntropyLoss()
for batch, (X, y) in enumerate(ptrain_data):
    # Compute prediction and loss
        pred = model(X.to(device))
        print(pred)
        print(y[0].to(device))
        loss = loss_fn(pred, y[0].to(device).type(torch.float32))

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 10 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f} ")
# Out:
# Index: 0
# Batch number 0
# tensor([-1.3770, -2.5254], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.275467
# Index: 1
# Batch number 1
# tensor([-0.3802, -4.5946], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 2
# Batch number 2
# tensor([-2.3151, -1.9940], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 3
# Batch number 3
# tensor([-3.5006, -0.3563], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 4
# Batch number 4
# tensor([-3.6882, -2.1133], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 5
# Batch number 5
# tensor([-3.9019, -3.3074], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 6
# Batch number 6
# tensor([-0.2469, -0.6003], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 7
# Batch number 7
# tensor([-1.1850, -3.1779], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 8
# Batch number 8
# tensor([-0.4875, -1.0154], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 9
# Batch number 9
# tensor([-0.2961, -0.4003], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 10
# Batch number 10
# tensor([-3.9599, -4.9308], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 1.292081
# Index: 11
# Batch number 11
# tensor([-1.5775, -1.1830], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 12
# Batch number 12
# tensor([-2.7667, -2.2312], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 13
# Batch number 13
# tensor([-0.7076, -1.1347], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 14
# Batch number 14
# tensor([-3.4598, -3.9927], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 15
# Batch number 15
# tensor([-0.8133, -0.0667], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 16
# Batch number 16
# tensor([-2.0404, -1.9237], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 17
# Batch number 17
# tensor([-1.5484, -2.4010], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 18
# Batch number 18
# tensor([-1.8822, -2.4335], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 19
# Batch number 19
# tensor([-0.7849, -0.9887], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 20
# Batch number 20
# tensor([-0.8710, -1.3323], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.950213
# Index: 21
# Batch number 21
# tensor([-0.6869, -0.2692], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 22
# Batch number 22
# tensor([-2.3359, -1.9643], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 23
# Batch number 23
# tensor([-5.9157,  0.2009], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 24
# Batch number 24
# tensor([-0.5391, -2.8798], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 25
# Batch number 25
# tensor([-3.3078, -4.0333], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 26
# Batch number 26
# tensor([ 4.8831, -5.3366], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 27
# Batch number 27
# tensor([ 2.4772, -3.6975], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 28
# Batch number 28
# tensor([-0.4495, -1.6874], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 29
# Batch number 29
# tensor([ 0.7949, -1.8770], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 30
# Batch number 30
# tensor([ 0.3902, -1.4448], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 1.983069
# Index: 31
# Batch number 31
# tensor([-1.6017, -2.9319], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 32
# Batch number 32
# tensor([ 0.1453, -2.4637], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 33
# Batch number 33
# tensor([ 2.6745, -2.9602], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 34
# Batch number 34
# tensor([-0.4288, -1.3958], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 35
# Batch number 35
# tensor([ 0.1412, -1.2576], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 36
# Batch number 36
# tensor([ 1.5463, -1.8203], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 37
# Batch number 37
# tensor([-0.6554, -1.4311], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 38
# Batch number 38
# tensor([ 2.4267, -2.8888], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 39
# Batch number 39
# tensor([-0.5152, -1.4073], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 40
# Batch number 40
# tensor([-1.1327, -2.1433], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.310437
# Index: 41
# Batch number 41
# tensor([-0.6404, -1.2117], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 42
# Batch number 42
# tensor([-1.1110, -1.5474], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 43
# Batch number 43
# tensor([ 0.5107, -0.6780], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 44
# Batch number 44
# tensor([ 0.5752, -0.9005], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 45
# Batch number 45
# tensor([-0.7129, -1.2363], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 46
# Batch number 46
# tensor([ 0.7731, -1.0502], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 47
# Batch number 47
# tensor([-0.1127, -0.6348], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 48
# Batch number 48
# tensor([ 0.3264, -0.5496], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 49
# Batch number 49
# tensor([-1.0414, -1.7627], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 50
# Batch number 50
# tensor([-0.6746, -0.9995], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.543864
# Index: 51
# Batch number 51
# tensor([-0.6266, -1.0583], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 52
# Batch number 52
# tensor([-1.1618, -1.4327], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 53
# Batch number 53
# tensor([-1.3026, -1.7867], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 54
# Batch number 54
# tensor([ 0.2931, -0.6938], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 55
# Batch number 55
# tensor([ 0.4555, -0.9815], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 56
# Batch number 56
# tensor([-0.7839, -1.3972], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 57
# Batch number 57
# tensor([ 0.4917, -0.6133], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 58
# Batch number 58
# tensor([-0.8573, -1.5482], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 59
# Batch number 59
# tensor([ 0.3017, -0.5816], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 60
# Batch number 60
# tensor([-0.9442, -1.8431], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 1.240314
# Index: 61
# Batch number 61
# tensor([-0.7629, -1.2166], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 62
# Batch number 62
# tensor([-1.0579, -1.6994], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 63
# Batch number 63
# tensor([-0.0260, -0.4240], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 64
# Batch number 64
# tensor([-0.5190, -0.8832], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 65
# Batch number 65
# tensor([-1.4384, -1.6586], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 66
# Batch number 66
# tensor([ 0.0355, -0.4215], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 67
# Batch number 67
# tensor([ 0.1683, -3.2702], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 68
# Batch number 68
# tensor([-1.2553, -1.1195], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 69
# Batch number 69
# tensor([-1.4500, -1.4490], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 70
# Batch number 70
# tensor([-0.7624, -1.0266], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.569753
# Index: 71
# Batch number 71
# tensor([-0.9184, -0.5195], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 72
# Batch number 72
# tensor([-0.5964, -1.0685], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 73
# Batch number 73
# tensor([-2.4786, -3.5133], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 74
# Batch number 74
# tensor([-2.3428, -3.9636], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 75
# Batch number 75
# tensor([-0.9480, -0.2798], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 76
# Batch number 76
# tensor([-0.8197, -1.8380], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 77
# Batch number 77
# tensor([-0.8150, -1.4889], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 78
# Batch number 78
# tensor([-0.8339, -1.7228], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 79
# Batch number 79
# tensor([-1.5993, -0.1631], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 80
# Batch number 80
# tensor([-1.0040, -2.1430], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.277722
# Index: 81
# Batch number 81
# tensor([-1.1798, -2.6471], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 82
# Batch number 82
# tensor([-0.7257, -1.9767], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 83
# Batch number 83
# tensor([-0.4265, -1.4981], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 84
# Batch number 84
# tensor([-1.1657, -2.6025], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 85
# Batch number 85
# tensor([-0.3230, -1.3743], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 86
# Batch number 86
# tensor([-0.1002, -0.8420], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 87
# Batch number 87
# tensor([-0.4601, -1.5494], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 88
# Batch number 88
# tensor([-0.3883, -1.4437], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 89
# Batch number 89
# tensor([-0.1619, -1.0713], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 90
# Batch number 90
# tensor([-0.3930, -1.6215], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.256746
# Index: 91
# Batch number 91
# tensor([-2.0612, -6.2795], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 92
# Batch number 92
# tensor([-0.5188, -2.0076], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 93
# Batch number 93
# tensor([-4.2611, -0.5065], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 94
# Batch number 94
# tensor([ 0.1720, -0.4326], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 95
# Batch number 95
# tensor([ 0.2746, -0.7135], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 96
# Batch number 96
# tensor([-0.2317, -2.1588], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 97
# Batch number 97
# tensor([-0.6990, -3.0472], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 98
# Batch number 98
# tensor([ 0.6462, -1.3763], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 99
# Batch number 99
# tensor([ 0.0299, -0.7981], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 100
# Batch number 100
# tensor([-0.5752, -1.7240], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 1.424189
# Index: 101
# Batch number 101
# tensor([-1.5333, -2.9830], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 102
# Batch number 102
# tensor([-0.9441, -2.2259], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 103
# Batch number 103
# tensor([-0.4026, -1.3615], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 104
# Batch number 104
# tensor([-1.4370, -3.4897], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 105
# Batch number 105
# tensor([-0.3284, -1.7125], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 106
# Batch number 106
# tensor([-0.5729, -1.5599], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 107
# Batch number 107
# tensor([-0.3813, -1.3570], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 108
# Batch number 108
# tensor([ 0.2866, -0.5889], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 109
# Batch number 109
# tensor([ 0.3442, -0.8313], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 110
# Batch number 110
# tensor([-0.2164, -1.0066], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.374142
# Index: 111
# Batch number 111
# tensor([ 0.3118, -0.6066], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 112
# Batch number 112
# tensor([-0.4496, -1.5963], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 113
# Batch number 113
# tensor([-0.4776, -1.3859], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 114
# Batch number 114
# tensor([-0.3707, -1.0667], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 115
# Batch number 115
# tensor([-0.2874, -0.9864], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 116
# Batch number 116
# tensor([ 0.2817, -0.5583], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 117
# Batch number 117
# tensor([-0.7083, -1.7497], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 118
# Batch number 118
# tensor([ 0.2115, -0.3857], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 119
# Batch number 119
# tensor([-0.7409, -1.6929], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 120
# Batch number 120
# tensor([-1.3698, -2.5568], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.266295
# Index: 121
# Batch number 121
# tensor([-1.6627, -3.3376], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 122
# Batch number 122
# tensor([ 0.4297, -0.6073], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 123
# Batch number 123
# tensor([-1.7683, -3.7270], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 124
# Batch number 124
# tensor([-1.0976, -2.6589], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 125
# Batch number 125
# tensor([ 0.2649, -1.3487], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 126
# Batch number 126
# tensor([-0.1812, -1.0468], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 127
# Batch number 127
# tensor([-0.7529, -2.0299], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 128
# Batch number 128
# tensor([-1.1617, -2.9981], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 129
# Batch number 129
# tensor([-1.0134, -2.8793], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 130
# Batch number 130
# tensor([-0.6441, -1.4572], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.367065
# Index: 131
# Batch number 131
# tensor([-0.2345, -0.8915], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 132
# Batch number 132
# tensor([ 0.1407, -0.4271], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 133
# Batch number 133
# tensor([ 0.2351, -0.3728], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 134
# Batch number 134
# tensor([-1.1271, -2.3636], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 135
# Batch number 135
# tensor([ 0.3977, -0.5969], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 136
# Batch number 136
# tensor([-1.6504, -3.5662], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 137
# Batch number 137
# tensor([ 0.1807, -0.3877], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 138
# Batch number 138
# tensor([ 0.2033, -0.2681], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 139
# Batch number 139
# tensor([-0.3605, -1.3393], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 140
# Batch number 140
# tensor([-1.3974, -3.5459], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.110335
# Index: 141
# Batch number 141
# tensor([-0.2670, -1.2481], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 142
# Batch number 142
# tensor([-1.1628, -3.3868], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 143
# Batch number 143
# tensor([-0.6034, -2.2318], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 144
# Batch number 144
# tensor([-0.8679, -3.2219], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 145
# Batch number 145
# tensor([ 0.2192, -0.4469], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 146
# Batch number 146
# tensor([ 0.1742, -0.5160], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 147
# Batch number 147
# tensor([ 0.2049, -0.3453], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 148
# Batch number 148
# tensor([-0.9829, -3.2895], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 149
# Batch number 149
# tensor([-1.0209, -2.2955], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 150
# Batch number 150
# tensor([-0.9259, -2.3417], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.217309
# Index: 151
# Batch number 151
# tensor([-0.7284, -2.0778], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 152
# Batch number 152
# tensor([-0.1649, -0.8680], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 153
# Batch number 153
# tensor([-0.3301, -1.0554], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 154
# Batch number 154
# tensor([ 0.1149, -0.3423], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 155
# Batch number 155
# tensor([-0.9508, -1.9547], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 156
# Batch number 156
# tensor([ 0.6132, -0.5239], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 157
# Batch number 157
# tensor([-1.4115, -1.9550], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 158
# Batch number 158
# tensor([-0.4915, -1.0352], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 159
# Batch number 159
# tensor([-0.6692, -1.3380], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 160
# Batch number 160
# tensor([-0.9355, -1.8331], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.341845
# Index: 161
# Batch number 161
# tensor([-1.2977, -2.5911], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 162
# Batch number 162
# tensor([-0.2361, -0.9301], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 163
# Batch number 163
# tensor([ 0.1478, -0.2333], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 164
# Batch number 164
# tensor([-0.6725, -1.5391], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 165
# Batch number 165
# tensor([-0.3566, -1.1012], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 166
# Batch number 166
# tensor([-0.1675, -0.7498], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 167
# Batch number 167
# tensor([-0.7171, -1.4567], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 168
# Batch number 168
# tensor([-0.5338, -1.0948], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 169
# Batch number 169
# tensor([-0.7471, -1.4015], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 170
# Batch number 170
# tensor([-0.4493, -0.9237], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.483807
# Index: 171
# Batch number 171
# tensor([-0.7022, -1.2680], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 172
# Batch number 172
# tensor([-0.3194, -0.6801], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 173
# Batch number 173
# tensor([-0.6380, -1.2697], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 174
# Batch number 174
# tensor([-0.9547, -1.4381], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 175
# Batch number 175
# tensor([-0.0156, -0.3747], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 176
# Batch number 176
# tensor([-0.7531, -1.3368], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 177
# Batch number 177
# tensor([-0.1587, -0.6342], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 178
# Batch number 178
# tensor([-0.5512, -1.1002], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 179
# Batch number 179
# tensor([-1.5211, -2.5423], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 180
# Batch number 180
# tensor([-0.2142, -0.4894], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.840212
# Index: 181
# Batch number 181
# tensor([-0.3444, -0.9709], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 182
# Batch number 182
# tensor([-0.2420, -0.8382], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 183
# Batch number 183
# tensor([-0.3285, -0.9326], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 184
# Batch number 184
# tensor([-0.1819, -0.6998], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 185
# Batch number 185
# tensor([-0.3448, -0.5226], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 186
# Batch number 186
# tensor([-0.6484, -1.5099], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 187
# Batch number 187
# tensor([-1.6471, -3.3671], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 188
# Batch number 188
# tensor([-0.0275, -0.3276], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 189
# Batch number 189
# tensor([-0.4183, -1.2689], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 190
# Batch number 190
# tensor([-0.8979, -2.1744], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.246086
# Index: 191
# Batch number 191
# tensor([-0.0514, -0.3162], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 192
# Batch number 192
# tensor([-0.2298, -1.0046], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 193
# Batch number 193
# tensor([-0.6934, -2.0715], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 194
# Batch number 194
# tensor([-0.5670, -1.9114], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 195
# Batch number 195
# tensor([-0.3346, -1.4711], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 196
# Batch number 196
# tensor([-0.5597, -2.1737], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 197
# Batch number 197
# tensor([-0.4750, -0.5599], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 198
# Batch number 198
# tensor([-0.4224, -1.8936], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 199
# Batch number 199
# tensor([-0.3545, -1.6414], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 200
# Batch number 200
# tensor([-0.0830, -0.5861], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.975959
# Index: 201
# Batch number 201
# tensor([-1.1605, -3.2726], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 202
# Batch number 202
# tensor([-0.5350, -1.9826], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 203
# Batch number 203
# tensor([-1.3741, -4.2566], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 204
# Batch number 204
# tensor([-0.4447, -1.8661], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 205
# Batch number 205
# tensor([-0.7356, -2.7947], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 206
# Batch number 206
# tensor([-0.4027, -1.9494], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 207
# Batch number 207
# tensor([-0.5335, -0.5892], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 208
# Batch number 208
# tensor([-4.4339, -2.6385], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 209
# Batch number 209
# tensor([-1.0174, -2.9070], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 210
# Batch number 210
# tensor([-0.1675, -0.3175], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.770947
# Index: 211
# Batch number 211
# tensor([-0.6641, -0.5290], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 212
# Batch number 212
# tensor([-1.1216, -2.4628], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 213
# Batch number 213
# tensor([-0.7982, -1.9486], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 214
# Batch number 214
# tensor([-0.2367, -0.3511], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 215
# Batch number 215
# tensor([-0.4319, -1.3770], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 216
# Batch number 216
# tensor([-1.1781, -0.7601], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 217
# Batch number 217
# tensor([-1.5279, -0.7932], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 218
# Batch number 218
# tensor([-0.5641, -1.4967], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 219
# Batch number 219
# tensor([-0.8722, -1.6251], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 220
# Batch number 220
# tensor([-0.5364, -0.8954], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.529694
# Index: 221
# Batch number 221
# tensor([-0.6473, -0.7051], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 222
# Batch number 222
# tensor([-1.2222, -1.9177], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 223
# Batch number 223
# tensor([-0.2767, -0.2914], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 224
# Batch number 224
# tensor([-0.6498, -1.1931], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 225
# Batch number 225
# tensor([-1.9405, -2.7724], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 226
# Batch number 226
# tensor([-0.5650, -1.1880], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 227
# Batch number 227
# tensor([-0.1792, -0.5510], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 228
# Batch number 228
# tensor([-0.2245, -0.7435], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 229
# Batch number 229
# tensor([-0.6525, -1.4112], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 230
# Batch number 230
# tensor([-0.5630, -1.3162], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 1.139045
# Index: 231
# Batch number 231
# tensor([-0.4234, -0.8403], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 232
# Batch number 232
# tensor([-0.9982, -1.8113], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 233
# Batch number 233
# tensor([-0.4327, -0.7602], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 234
# Batch number 234
# tensor([-1.3010, -0.5598], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 235
# Batch number 235
# tensor([-1.6108, -0.5661], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 236
# Batch number 236
# tensor([-1.1353, -1.2457], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 237
# Batch number 237
# tensor([-0.5945, -0.8514], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 238
# Batch number 238
# tensor([-0.5565, -0.8906], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 239
# Batch number 239
# tensor([-0.4272, -0.8829], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 240
# Batch number 240
# tensor([-2.5078, -0.8068], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 1.868674
# Index: 241
# Batch number 241
# tensor([-2.1837, -1.3248], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 242
# Batch number 242
# tensor([-0.3531, -0.9702], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 243
# Batch number 243
# tensor([-1.4813, -0.8336], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 244
# Batch number 244
# tensor([-1.3825, -0.6425], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 245
# Batch number 245
# tensor([-0.4925, -0.8414], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 246
# Batch number 246
# tensor([-0.6713, -0.3581], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 247
# Batch number 247
# tensor([-1.3630, -0.5100], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 248
# Batch number 248
# tensor([-4.7834, -1.0995], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 249
# Batch number 249
# tensor([-0.5117, -0.5499], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 250
# Batch number 250
# tensor([-0.5281, -1.2821], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.385598
# Index: 251
# Batch number 251
# tensor([-0.7521, -1.6513], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 252
# Batch number 252
# tensor([-0.4358, -1.3241], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 253
# Batch number 253
# tensor([-0.4095, -0.5273], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 254
# Batch number 254
# tensor([-1.2963, -2.5116], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 255
# Batch number 255
# tensor([-3.1476, -0.7395], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 256
# Batch number 256
# tensor([-2.8172, -0.5999], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 257
# Batch number 257
# tensor([-0.3857, -0.9818], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 258
# Batch number 258
# tensor([-0.4572, -1.3102], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 259
# Batch number 259
# tensor([-0.4922, -1.4574], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 260
# Batch number 260
# tensor([-0.4498, -0.2986], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.620388
# Index: 261
# Batch number 261
# tensor([-3.1081, -0.5078], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 262
# Batch number 262
# tensor([-1.5315, -3.1203], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 263
# Batch number 263
# tensor([-0.6994, -1.7244], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 264
# Batch number 264
# tensor([-0.6213, -0.9803], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 265
# Batch number 265
# tensor([-1.4307, -0.2889], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 266
# Batch number 266
# tensor([-1.1689, -1.3162], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 267
# Batch number 267
# tensor([-3.9755, -0.4552], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 268
# Batch number 268
# tensor([-0.1062, -0.3914], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 269
# Batch number 269
# tensor([-0.4100, -0.3952], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 270
# Batch number 270
# tensor([-0.8375, -0.6198], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.590241
# Index: 271
# Batch number 271
# tensor([-1.0260, -2.0430], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 272
# Batch number 272
# tensor([-0.6250, -1.0012], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 273
# Batch number 273
# tensor([-0.0718, -0.2576], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 274
# Batch number 274
# tensor([-2.3523, -1.1244], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 275
# Batch number 275
# tensor([-0.4453, -0.9029], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 276
# Batch number 276
# tensor([-0.3278, -0.7892], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 277
# Batch number 277
# tensor([-0.7265, -1.3747], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 278
# Batch number 278
# tensor([-0.3064, -0.8445], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 279
# Batch number 279
# tensor([-0.8753, -1.5853], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 280
# Batch number 280
# tensor([-0.0258, -0.2132], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.791213
# Index: 281
# Batch number 281
# tensor([-0.9914, -1.5061], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 282
# Batch number 282
# tensor([-0.2824, -0.7208], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 283
# Batch number 283
# tensor([-0.0778, -0.4670], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 284
# Batch number 284
# tensor([-0.2524, -0.6750], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 285
# Batch number 285
# tensor([-0.4581, -1.0380], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 286
# Batch number 286
# tensor([-0.5497, -0.3693], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 287
# Batch number 287
# tensor([-0.7901, -1.5746], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 288
# Batch number 288
# tensor([-0.5567, -1.2054], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 289
# Batch number 289
# tensor([-0.2764, -0.6611], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 290
# Batch number 290
# tensor([-0.9484, -2.1028], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.274006
# Index: 291
# Batch number 291
# tensor([-0.6986, -1.8390], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 292
# Batch number 292
# tensor([-0.5389, -1.6201], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 293
# Batch number 293
# tensor([-0.5408, -0.6997], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 294
# Batch number 294
# tensor([-0.9919, -0.4356], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 295
# Batch number 295
# tensor([-0.8773, -0.3667], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 296
# Batch number 296
# tensor([-0.1722, -0.8588], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 297
# Batch number 297
# tensor([-0.1348, -0.8517], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 298
# Batch number 298
# tensor([-2.4598, -0.6130], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 299
# Batch number 299
# tensor([ 0.0003, -0.2481], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 300
# Batch number 300
# tensor([-0.2408, -1.1807], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 1.269645
# Index: 301
# Batch number 301
# tensor([-1.7622, -0.9701], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 302
# Batch number 302
# tensor([-0.2064, -1.0071], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 303
# Batch number 303
# tensor([-0.1315, -0.8558], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 304
# Batch number 304
# tensor([-0.8061, -0.8466], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 305
# Batch number 305
# tensor([ 0.0950, -0.2169], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 306
# Batch number 306
# tensor([-0.5197, -1.7618], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 307
# Batch number 307
# tensor([-0.1349, -0.3716], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 308
# Batch number 308
# tensor([-0.4101, -0.4398], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 309
# Batch number 309
# tensor([-0.0531, -0.3153], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 310
# Batch number 310
# tensor([-0.5840, -2.0044], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 1.636774
# Index: 311
# Batch number 311
# tensor([-0.0812, -0.5998], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 312
# Batch number 312
# tensor([-0.6194, -0.5885], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 313
# Batch number 313
# tensor([-0.1916, -0.8108], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 314
# Batch number 314
# tensor([-0.4663, -1.1968], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 315
# Batch number 315
# tensor([-0.6936, -0.5636], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 316
# Batch number 316
# tensor([-0.2068, -0.7322], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 317
# Batch number 317
# tensor([-0.2164, -0.7845], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 318
# Batch number 318
# tensor([-0.5001, -1.3287], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 319
# Batch number 319
# tensor([-0.6380, -1.5585], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 320
# Batch number 320
# tensor([-0.2347, -0.9364], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.402622
# Index: 321
# Batch number 321
# tensor([-0.3544, -1.2310], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 322
# Batch number 322
# tensor([-0.7046, -1.7808], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 323
# Batch number 323
# tensor([-0.3407, -0.8892], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 324
# Batch number 324
# tensor([-0.1819, -0.6814], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 325
# Batch number 325
# tensor([-0.2659, -0.8154], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 326
# Batch number 326
# tensor([-0.1489, -0.6914], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 327
# Batch number 327
# tensor([-0.3955, -1.0741], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 328
# Batch number 328
# tensor([-1.0396, -2.4393], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 329
# Batch number 329
# tensor([-0.0036, -0.2387], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 330
# Batch number 330
# tensor([-0.1817, -0.8638], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.409170
# Index: 331
# Batch number 331
# tensor([-0.7866, -0.5241], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 332
# Batch number 332
# tensor([-0.8214, -2.2778], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 333
# Batch number 333
# tensor([-0.2892, -0.5605], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 334
# Batch number 334
# tensor([-0.1123, -0.4843], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 335
# Batch number 335
# tensor([-0.3871, -0.9249], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 336
# Batch number 336
# tensor([-0.1929, -0.2656], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 337
# Batch number 337
# tensor([-0.1460, -0.6419], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 338
# Batch number 338
# tensor([-0.4162, -1.0849], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 339
# Batch number 339
# tensor([-0.2978, -0.9138], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 340
# Batch number 340
# tensor([-0.1530, -0.3184], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.613839
# Index: 341
# Batch number 341
# tensor([-0.3025, -0.6338], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 342
# Batch number 342
# tensor([-0.2086, -0.2944], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 343
# Batch number 343
# tensor([-0.4817, -1.2768], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 344
# Batch number 344
# tensor([-0.2932, -0.4194], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 345
# Batch number 345
# tensor([-0.6227, -1.1084], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 346
# Batch number 346
# tensor([-0.1749, -0.4562], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 347
# Batch number 347
# tensor([-0.8536, -0.5264], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 348
# Batch number 348
# tensor([-1.2720, -0.6795], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 349
# Batch number 349
# tensor([-0.4344, -0.3159], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 350
# Batch number 350
# tensor([-0.2180, -0.4754], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.830141
# Index: 351
# Batch number 351
# tensor([-3.6432, -1.3859], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 352
# Batch number 352
# tensor([-0.4224, -0.9366], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 353
# Batch number 353
# tensor([-0.5334, -1.0873], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 354
# Batch number 354
# tensor([-0.0578, -0.4389], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 355
# Batch number 355
# tensor([-0.2722, -0.7320], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 356
# Batch number 356
# tensor([-0.2660, -0.7413], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 357
# Batch number 357
# tensor([-0.0715, -0.3689], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 358
# Batch number 358
# tensor([ 0.0591, -0.2427], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 359
# Batch number 359
# tensor([-0.2015, -0.5141], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 360
# Batch number 360
# tensor([ 0.0978, -0.1911], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.847981
# Index: 361
# Batch number 361
# tensor([-0.6452, -1.0272], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 362
# Batch number 362
# tensor([-0.2629, -0.4998], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 363
# Batch number 363
# tensor([-0.0823, -0.3479], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 364
# Batch number 364
# tensor([-0.2026, -0.4380], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 365
# Batch number 365
# tensor([-0.3457, -0.7178], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 366
# Batch number 366
# tensor([-1.1690, -1.4695], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 367
# Batch number 367
# tensor([-0.9328, -1.4428], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 368
# Batch number 368
# tensor([-0.5977, -0.8322], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 369
# Batch number 369
# tensor([-0.5558, -0.7799], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 370
# Batch number 370
# tensor([-0.3581, -0.5671], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.594103
# Index: 371
# Batch number 371
# tensor([-0.8541, -1.1345], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 372
# Batch number 372
# tensor([-0.5798, -0.9666], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 373
# Batch number 373
# tensor([-0.7422, -1.1607], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 374
# Batch number 374
# tensor([ 0.1171, -0.1669], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 375
# Batch number 375
# tensor([-0.5225, -1.0364], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 376
# Batch number 376
# tensor([-0.1220, -0.4212], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 377
# Batch number 377
# tensor([-0.0861, -0.4444], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 378
# Batch number 378
# tensor([-0.0795, -0.4470], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 379
# Batch number 379
# tensor([-0.2292, -0.6052], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 380
# Batch number 380
# tensor([-0.3481, -0.8618], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.468897
# Index: 381
# Batch number 381
# tensor([-0.1098, -0.5584], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 382
# Batch number 382
# tensor([ 0.1054, -0.1827], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 383
# Batch number 383
# tensor([-0.0046, -0.2696], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 384
# Batch number 384
# tensor([-0.8028, -1.6821], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 385
# Batch number 385
# tensor([-1.0745, -2.3372], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 386
# Batch number 386
# tensor([-0.2351, -0.4419], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 387
# Batch number 387
# tensor([-0.3346, -0.4867], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 388
# Batch number 388
# tensor([-0.6670, -1.0722], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 389
# Batch number 389
# tensor([-0.3112, -0.7569], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 390
# Batch number 390
# tensor([ 0.0437, -0.2114], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.828809
# Index: 391
# Batch number 391
# tensor([-0.0807, -0.4744], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 392
# Batch number 392
# tensor([-0.5833, -1.1084], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 393
# Batch number 393
# tensor([-0.6740, -1.2118], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 394
# Batch number 394
# tensor([-0.0780, -0.5470], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 395
# Batch number 395
# tensor([-0.1790, -0.3591], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 396
# Batch number 396
# tensor([-0.7134, -0.6632], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 397
# Batch number 397
# tensor([-0.1621, -0.7100], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 398
# Batch number 398
# tensor([-0.0090, -0.4446], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 399
# Batch number 399
# tensor([-0.0825, -0.6322], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 400
# Batch number 400
# tensor([-0.4805, -1.3835], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.340294
# Index: 401
# Batch number 401
# tensor([-0.2289, -0.4228], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 402
# Batch number 402
# tensor([-0.3706, -0.4939], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 403
# Batch number 403
# tensor([-0.1640, -0.6739], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 404
# Batch number 404
# tensor([-0.1061, -0.5171], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 405
# Batch number 405
# tensor([-0.1582, -0.3705], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 406
# Batch number 406
# tensor([-0.2801, -1.0423], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 407
# Batch number 407
# tensor([-0.2058, -0.6692], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 408
# Batch number 408
# tensor([-0.1438, -0.3759], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 409
# Batch number 409
# tensor([-0.1543, -0.6630], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 410
# Batch number 410
# tensor([-0.2914, -0.7591], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.486374
# Index: 411
# Batch number 411
# tensor([-0.4234, -1.1697], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 412
# Batch number 412
# tensor([-0.2374, -0.6483], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 413
# Batch number 413
# tensor([-0.3542, -0.8910], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 414
# Batch number 414
# tensor([-0.4182, -0.4900], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 415
# Batch number 415
# tensor([-0.0908, -0.5342], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 416
# Batch number 416
# tensor([-0.1930, -0.2974], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 417
# Batch number 417
# tensor([-0.5325, -1.2684], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 418
# Batch number 418
# tensor([-0.7711, -1.7630], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 419
# Batch number 419
# tensor([-0.5190, -1.0581], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 420
# Batch number 420
# tensor([-0.1619, -0.5520], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.517025
# Index: 421
# Batch number 421
# tensor([-0.0068, -0.2216], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 422
# Batch number 422
# tensor([-0.0104, -0.3854], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 423
# Batch number 423
# tensor([-0.2982, -0.8581], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 424
# Batch number 424
# tensor([-0.0604, -0.2459], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 425
# Batch number 425
# tensor([-0.3928, -0.9559], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 426
# Batch number 426
# tensor([-0.7109, -0.5574], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 427
# Batch number 427
# tensor([-0.4062, -0.3707], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 428
# Batch number 428
# tensor([-0.7738, -0.4884], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 429
# Batch number 429
# tensor([-0.2060, -0.2574], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 430
# Batch number 430
# tensor([-0.1973, -0.2630], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.660820
# Index: 431
# Batch number 431
# tensor([-0.2735, -0.4900], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 432
# Batch number 432
# tensor([-1.2698, -0.6407], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 433
# Batch number 433
# tensor([-0.8598, -1.7793], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 434
# Batch number 434
# tensor([-0.1294, -0.2620], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 435
# Batch number 435
# tensor([-0.2520, -0.7256], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 436
# Batch number 436
# tensor([-0.1388, -0.2750], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 437
# Batch number 437
# tensor([-0.7189, -0.5321], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 438
# Batch number 438
# tensor([-0.2107, -0.3290], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 439
# Batch number 439
# tensor([-0.0974, -0.6752], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 440
# Batch number 440
# tensor([-0.1142, -0.6462], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.994084
# Index: 441
# Batch number 441
# tensor([-0.8421, -1.7221], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 442
# Batch number 442
# tensor([-0.3949, -0.7157], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 443
# Batch number 443
# tensor([-0.8858, -0.5298], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 444
# Batch number 444
# tensor([-0.3886, -0.8769], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 445
# Batch number 445
# tensor([-0.5797, -1.1706], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 446
# Batch number 446
# tensor([-0.2842, -0.6558], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 447
# Batch number 447
# tensor([-0.2843, -0.3156], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 448
# Batch number 448
# tensor([-0.1109, -0.4972], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 449
# Batch number 449
# tensor([-0.1750, -0.4691], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 450
# Batch number 450
# tensor([-0.3449, -1.1106], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 1.147586
# Index: 451
# Batch number 451
# tensor([-1.0270, -2.1060], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 452
# Batch number 452
# tensor([-0.4477, -0.4199], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 453
# Batch number 453
# tensor([-0.2981, -0.4262], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 454
# Batch number 454
# tensor([-0.1221, -0.3072], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 455
# Batch number 455
# tensor([-0.1860, -0.3051], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 456
# Batch number 456
# tensor([-0.3432, -0.7155], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 457
# Batch number 457
# tensor([-0.7259, -0.3985], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 458
# Batch number 458
# tensor([-0.4312, -0.7012], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 459
# Batch number 459
# tensor([-0.4682, -0.2772], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 460
# Batch number 460
# tensor([-1.7222, -0.6114], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.284651
# Index: 461
# Batch number 461
# tensor([-1.0748, -0.9275], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 462
# Batch number 462
# tensor([-0.6242, -0.2845], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 463
# Batch number 463
# tensor([-0.9786, -0.4555], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 464
# Batch number 464
# tensor([-0.7192, -1.0175], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 465
# Batch number 465
# tensor([-1.1559, -0.3810], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 466
# Batch number 466
# tensor([-0.1922, -0.4333], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 467
# Batch number 467
# tensor([-0.4247, -0.8565], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 468
# Batch number 468
# tensor([-1.4040, -0.4513], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 469
# Batch number 469
# tensor([-0.6923, -1.2745], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 470
# Batch number 470
# tensor([-0.5266, -0.5470], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.682994
# Index: 471
# Batch number 471
# tensor([-0.4178, -0.6187], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 472
# Batch number 472
# tensor([-0.9282, -1.8691], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 473
# Batch number 473
# tensor([-0.7658, -0.3005], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 474
# Batch number 474
# tensor([-0.4563, -0.2354], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 475
# Batch number 475
# tensor([-0.6401, -1.5346], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 476
# Batch number 476
# tensor([-0.4535, -0.6113], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 477
# Batch number 477
# tensor([-0.5132, -0.9806], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 478
# Batch number 478
# tensor([-0.3019, -1.0290], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 479
# Batch number 479
# tensor([-0.6134, -0.2421], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 480
# Batch number 480
# tensor([-0.9056, -0.2595], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.421387
# Index: 481
# Batch number 481
# tensor([-3.4133, -0.4954], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 482
# Batch number 482
# tensor([-0.7522, -0.5213], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 483
# Batch number 483
# tensor([-0.4461, -1.4336], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 484
# Batch number 484
# tensor([-1.3529, -0.3040], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 485
# Batch number 485
# tensor([-0.4200, -1.2630], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 486
# Batch number 486
# tensor([-0.3756, -0.8992], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 487
# Batch number 487
# tensor([-0.6294, -0.2196], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 488
# Batch number 488
# tensor([-0.2346, -1.1271], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 489
# Batch number 489
# tensor([-0.2294, -1.0477], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 490
# Batch number 490
# tensor([-1.2591, -0.4336], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.363271
# Index: 491
# Batch number 491
# tensor([-0.2981, -0.5450], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 492
# Batch number 492
# tensor([-0.1621, -0.8839], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 493
# Batch number 493
# tensor([-0.3876, -0.6024], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 494
# Batch number 494
# tensor([-0.7389, -2.6741], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 495
# Batch number 495
# tensor([-0.8313, -3.3548], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 496
# Batch number 496
# tensor([-1.8209, -0.2461], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 497
# Batch number 497
# tensor([-0.1978, -1.4342], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 498
# Batch number 498
# tensor([-1.1475, -4.6519], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 499
# Batch number 499
# tensor([-0.8499, -1.7603], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 500
# Batch number 500
# tensor([-0.6058, -0.2234], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.520130
# Index: 501
# Batch number 501
# tensor([-0.6691, -0.1513], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 502
# Batch number 502
# tensor([-0.2268, -0.7675], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 503
# Batch number 503
# tensor([-0.3327, -0.9399], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 504
# Batch number 504
# ...
# tensor([0, 1])
# Index: 547
# Batch number 547
# tensor([-0.5467, -0.3519], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 548
# Batch number 548
# tensor([ 0.0025, -0.1961], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 549
# Batch number 549
# tensor([-0.1436, -1.0677], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 550
# Batch number 550
# tensor([-0.7383, -2.5210], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.155457
# Index: 551
# Batch number 551
# tensor([-0.6883, -2.6887], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 552
# Batch number 552
# tensor([-0.5129, -2.4507], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 553
# Batch number 553
# tensor([-1.3944, -0.5169], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 554
# Batch number 554
# tensor([-0.4562, -2.4413], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 555
# Batch number 555
# tensor([-1.6170, -0.8091], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 556
# Batch number 556
# tensor([-0.1392, -1.1443], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 557
# Batch number 557
# tensor([ 0.0534, -0.5033], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 558
# Batch number 558
# tensor([-0.1024, -1.1712], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 559
# Batch number 559
# tensor([-0.1529, -1.3531], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 560
# Batch number 560
# tensor([-0.2159, -1.4181], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.262760
# Index: 561
# Batch number 561
# tensor([-0.4629, -2.6438], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 562
# Batch number 562
# tensor([-0.3409, -1.2364], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 563
# Batch number 563
# tensor([-1.5081, -0.6317], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 564
# Batch number 564
# tensor([-0.5601, -0.3195], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 565
# Batch number 565
# tensor([-0.4267, -0.2696], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 566
# Batch number 566
# tensor([-0.2097, -0.9578], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 567
# Batch number 567
# tensor([-0.7271, -2.0484], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 568
# Batch number 568
# tensor([-0.0344, -0.6667], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 569
# Batch number 569
# tensor([-3.6059, -0.8518], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 570
# Batch number 570
# tensor([-0.1798, -1.0445], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 1.216157
# Index: 571
# Batch number 571
# tensor([-0.3318, -1.2608], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 572
# Batch number 572
# tensor([-0.4392, -0.2498], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 573
# Batch number 573
# tensor([-0.0205, -0.5968], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 574
# Batch number 574
# tensor([-0.2941, -1.2534], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 575
# Batch number 575
# tensor([-0.6457, -2.2135], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 576
# Batch number 576
# tensor([-0.9751, -0.3132], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 577
# Batch number 577
# tensor([-0.0363, -0.7679], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 578
# Batch number 578
# tensor([-0.2461, -0.8816], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 579
# Batch number 579
# tensor([-0.5147, -0.2669], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 580
# Batch number 580
# tensor([-0.1438, -1.0703], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.333566
# Index: 581
# Batch number 581
# tensor([-4.1443, -0.7554], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 582
# Batch number 582
# tensor([-0.2779, -0.2131], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 583
# Batch number 583
# tensor([-0.0656, -0.7901], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 584
# Batch number 584
# tensor([-0.0511, -0.8329], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 585
# Batch number 585
# tensor([-0.0909, -1.0390], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 586
# Batch number 586
# tensor([-0.2561, -1.3397], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 587
# Batch number 587
# tensor([-8.7574, -1.7704], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 588
# Batch number 588
# tensor([-1.3848, -0.4149], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 589
# Batch number 589
# tensor([-2.2897, -1.4386], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 590
# Batch number 590
# tensor([ 0.0991, -0.9685], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.295518
# Index: 591
# Batch number 591
# tensor([-0.1997, -1.7904], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 592
# Batch number 592
# tensor([-0.5256, -0.8419], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 593
# Batch number 593
# tensor([-0.0512, -0.4334], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 594
# Batch number 594
# tensor([-0.0450, -1.4851], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 595
# Batch number 595
# tensor([-0.5378, -0.3350], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 596
# Batch number 596
# tensor([-0.3204, -1.3786], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 597
# Batch number 597
# tensor([-0.0947, -0.2419], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 598
# Batch number 598
# tensor([ 0.0648, -0.2374], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 599
# Batch number 599
# tensor([-0.3493, -1.5077], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 600
# Batch number 600
# tensor([-0.1255, -1.0744], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.327248
# Index: 601
# Batch number 601
# tensor([-0.3993, -0.6794], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 602
# Batch number 602
# tensor([-0.0971, -0.2030], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 603
# Batch number 603
# tensor([-0.2300, -1.3189], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 604
# Batch number 604
# tensor([ 0.0729, -0.7210], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 605
# Batch number 605
# tensor([-0.3382, -1.7882], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 606
# Batch number 606
# tensor([-1.2909, -0.4171], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 607
# Batch number 607
# tensor([-0.4720, -2.3514], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 608
# Batch number 608
# tensor([-0.0448, -1.0258], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 609
# Batch number 609
# tensor([-2.2862, -0.4296], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 610
# Batch number 610
# tensor([ 0.0329, -0.7215], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.385454
# Index: 611
# Batch number 611
# tensor([-1.5774, -0.3192], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 612
# Batch number 612
# tensor([-0.2551, -1.6065], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 613
# Batch number 613
# tensor([-0.2729, -1.7577], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 614
# Batch number 614
# tensor([-0.0967, -1.2331], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 615
# Batch number 615
# tensor([-0.5405, -3.0501], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 616
# Batch number 616
# tensor([-0.7005, -3.7501], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 617
# Batch number 617
# tensor([-0.5807, -3.0610], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 618
# Batch number 618
# tensor([-0.0275, -0.6962], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 619
# Batch number 619
# tensor([-0.1206, -0.1814], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 620
# Batch number 620
# tensor([-5.0657, -0.4495], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.009842
# Index: 621
# Batch number 621
# tensor([ 0.1033, -0.5077], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 622
# Batch number 622
# tensor([-1.2986, -0.2288], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 623
# Batch number 623
# tensor([-0.4744, -0.2894], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 624
# Batch number 624
# tensor([-0.2132, -1.1069], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 625
# Batch number 625
# tensor([-0.2011, -1.1490], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 626
# Batch number 626
# tensor([-0.0177, -0.8301], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 627
# Batch number 627
# tensor([-0.5424, -0.1937], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 628
# Batch number 628
# tensor([-0.2934, -0.1928], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 629
# Batch number 629
# tensor([-1.7540, -0.2605], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 630
# Batch number 630
# tensor([-0.2352, -0.2199], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.700844
# Index: 631
# Batch number 631
# tensor([-0.1901, -1.0793], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 632
# Batch number 632
# tensor([-0.4889, -1.7829], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 633
# Batch number 633
# tensor([-0.5626, -1.9857], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 634
# Batch number 634
# tensor([-0.3497, -1.2372], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 635
# Batch number 635
# tensor([-0.3473, -1.0603], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 636
# Batch number 636
# tensor([-0.0424, -0.6107], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 637
# Batch number 637
# tensor([-0.3959, -1.1889], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 638
# Batch number 638
# tensor([ 0.0068, -0.6225], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 639
# Batch number 639
# tensor([-1.6644, -0.4884], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 640
# Batch number 640
# tensor([ 0.0559, -0.1661], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.810262
# Index: 641
# Batch number 641
# tensor([-0.2723, -1.0151], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 642
# Batch number 642
# tensor([-0.3871, -1.0732], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 643
# Batch number 643
# tensor([-0.7745, -1.7927], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 644
# Batch number 644
# tensor([-0.0547, -0.6048], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 645
# Batch number 645
# tensor([-0.5113, -1.4771], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 646
# Batch number 646
# tensor([-0.6445, -0.2650], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 647
# Batch number 647
# tensor([-0.2014, -1.0241], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 648
# Batch number 648
# tensor([-0.2603, -1.1580], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 649
# Batch number 649
# tensor([-0.4129, -1.5927], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 650
# Batch number 650
# tensor([-0.4267, -0.2345], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.793909
# Index: 651
# Batch number 651
# tensor([-0.2774, -1.4609], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 652
# Batch number 652
# tensor([-0.1013, -1.0862], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 653
# Batch number 653
# tensor([-0.2932, -0.3479], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 654
# Batch number 654
# tensor([-0.5408, -2.5288], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 655
# Batch number 655
# tensor([-0.2508, -0.2350], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 656
# Batch number 656
# tensor([-1.0806, -0.3740], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 657
# Batch number 657
# tensor([-0.1618, -1.4521], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 658
# Batch number 658
# tensor([-0.6267, -2.3244], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 659
# Batch number 659
# tensor([-0.1743, -1.1801], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 660
# Batch number 660
# tensor([-0.5155, -0.2640], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.826799
# Index: 661
# Batch number 661
# tensor([-0.4144, -0.2655], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 662
# Batch number 662
# tensor([-0.7151, -0.3192], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 663
# Batch number 663
# tensor([ 0.0188, -0.3655], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 664
# Batch number 664
# tensor([-0.2267, -0.2048], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 665
# Batch number 665
# tensor([-0.1091, -0.8672], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 666
# Batch number 666
# tensor([-0.0242, -0.6500], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 667
# Batch number 667
# tensor([-1.5746, -0.3312], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 668
# Batch number 668
# tensor([-0.0603, -0.8043], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 669
# Batch number 669
# tensor([-1.1531, -0.2531], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 670
# Batch number 670
# tensor([-0.0479, -0.8153], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.381316
# Index: 671
# Batch number 671
# tensor([ 0.0361, -0.5575], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 672
# Batch number 672
# tensor([-0.2992, -0.3652], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 673
# Batch number 673
# tensor([-0.3061, -1.7022], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 674
# Batch number 674
# tensor([ 0.0106, -0.6799], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 675
# Batch number 675
# tensor([-0.4239, -2.2972], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 676
# Batch number 676
# tensor([-0.2574, -1.8898], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 677
# Batch number 677
# tensor([-0.6866, -0.2501], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 678
# Batch number 678
# tensor([-0.5646, -0.2309], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 679
# Batch number 679
# tensor([-0.9586, -4.8364], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 680
# Batch number 680
# tensor([-0.1379, -0.1959], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.664538
# Index: 681
# Batch number 681
# tensor([-0.6661, -0.2605], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 682
# Batch number 682
# tensor([-0.3263, -1.9195], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 683
# Batch number 683
# tensor([ 0.0075, -0.9456], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 684
# Batch number 684
# tensor([-3.5111, -0.4965], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 685
# Batch number 685
# tensor([-0.4374, -2.2689], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 686
# Batch number 686
# tensor([-0.0065, -0.4035], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 687
# Batch number 687
# tensor([-0.4346, -1.5738], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 688
# Batch number 688
# tensor([-0.0325, -0.6637], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 689
# Batch number 689
# tensor([-0.4065, -1.5596], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 690
# Batch number 690
# tensor([-0.0534, -0.6046], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.455050
# Index: 691
# Batch number 691
# tensor([-0.4816, -1.5858], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 692
# Batch number 692
# tensor([-0.1507, -0.6495], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 693
# Batch number 693
# tensor([-1.1342, -0.2409], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 694
# Batch number 694
# tensor([-0.0608, -0.1834], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 695
# Batch number 695
# tensor([-0.1669, -0.7173], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 696
# Batch number 696
# tensor([-0.6283, -0.2488], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 697
# Batch number 697
# tensor([-0.4579, -1.2002], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 698
# Batch number 698
# tensor([-0.6150, -1.6310], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 699
# Batch number 699
# tensor([-0.1127, -0.2313], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 700
# Batch number 700
# tensor([ 0.0532, -0.3900], grad_fn=<AddBackward0>)
# tensor([0, 1])
# loss: 0.939129
# Index: 701
# Batch number 701
# tensor([-0.0041, -0.4541], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 702
# Batch number 702
# tensor([-0.0066, -0.5076], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 703
# Batch number 703
# tensor([-1.8178, -0.3335], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 704
# Batch number 704
# tensor([-0.4634, -0.1947], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 705
# Batch number 705
# tensor([-0.2760, -1.1292], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 706
# Batch number 706
# tensor([-0.0497, -0.5979], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 707
# Batch number 707
# tensor([-0.1523, -0.9183], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 708
# Batch number 708
# tensor([-0.1079, -0.9412], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 709
# Batch number 709
# tensor([-0.2433, -0.4525], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 710
# Batch number 710
# tensor([-0.0936, -0.8919], grad_fn=<AddBackward0>)
# tensor([1, 0])
# loss: 0.371650
# Index: 711
# Batch number 711
# tensor([-0.6587, -0.2084], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 712
# Batch number 712
# tensor([-0.6028, -0.1891], grad_fn=<AddBackward0>)
# tensor([0, 1])
# Index: 713
# Batch number 713
# tensor([-0.2276, -1.4350], grad_fn=<AddBackward0>)
# tensor([1, 0])
# Index: 714
